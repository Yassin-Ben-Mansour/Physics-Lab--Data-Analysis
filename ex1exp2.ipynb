# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
from scipy.integrate import odeint

# %%
df = pd.read_excel('Classeur2b.xlsx')
df.head()
# Out:
#      t(s)     x(m)          y(m)
# 0  0.0667  0.00186 -2.270000e-19
# 1  0.1000  0.00371 -4.550000e-19
# 2  0.1330  0.00929 -1.140000e-18
# 3  0.1670  0.02040 -2.500000e-18
# 4  0.2000  0.03160 -3.870000e-18

# %%
t = np.array(df['t(s)']) - 0.0667
x = np.array(df['x(m)'])

# %%
plt.plot(t,x,'co')
plt.plot(t,x,'b')
plt.xlabel('Temps t(s)')
plt.ylabel('abscisse x(m)')
plt.title('La trajectoire x(t) avec les valeurs experiementales')
# Out:
# Text(0.5, 1.0, 'La trajectoire x(t) avec les valeurs experiementales')

# %%
m = x.max()
m
# Out:
# np.float64(0.342)

# %%
m = 0.515
g = 9.81
z = x-x[0]
Epp = m*g*z
plt.plot(t,Epp, 'ro')
plt.plot(t,Epp,'r')
plt.xlabel('Temps t(s)')
plt.ylabel('Energie potetnielle de pesanteurn Epp(J)')
plt.title('La variation de Epp en fonction du temps')
# Out:
# Text(0.5, 1.0, 'La variation de Epp en fonction du temps')
